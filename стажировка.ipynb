# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikhail-068/Scoring/blob/Vinokurov/%D1%81%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import openpyxl

# %%
import matplotlib.pyplot as plt

# %%
good = pd.read_excel(io='/content/drive/MyDrive/bases/стажировка_скоринг/2567_КИдлятеста_5000_безПИ.xlsx', skiprows=2)

# %%
bad = pd.read_excel(io='/content/drive/MyDrive/bases/стажировка_скоринг/2579_КИдлятеста_плохие_всего4588_безПИ.xlsx', skiprows=2)

# %%
name_colum = pd.read_excel(io='/content/drive/MyDrive/bases/стажировка_скоринг/названия столбцов.xlsx', engine='openpyxl')

# %%
good.describe()
# Out:
#          population        amount            psk       balance  \
# count  1.670830e+05  1.670600e+05  167060.000000  1.670600e+05
# mean   2.117029e+05  2.239342e+04     317.177628  2.499625e+04
# std    4.667561e+05  9.355534e+04    2100.120343  1.065992e+05
# min    3.237000e+03  0.000000e+00       0.000000  0.000000e+00
# 25%    3.259200e+04  5.000000e+03     237.250000  3.780000e+03
# 50%    1.268050e+05  1.000000e+04     364.920000  9.260500e+03
# 75%    1.822910e+05  1.591992e+04     365.000000  1.798412e+04
# max    5.383890e+06  1.309062e+07  844793.000000  1.377907e+07
#
#        current_indebtedness       expired  next_payment  \
# count          1.670600e+05  1.670600e+05  1.670600e+05
# mean           4.057929e+02  1.880645e+02  1.303574e+02
# std            1.207059e+04  9.108185e+03  6.501820e+03
# min            0.000000e+00  0.000000e+00  0.000000e+00
# 25%            0.000000e+00  0.000000e+00  0.000000e+00
# 50%            0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
colours = ['#000000', '#ffff00']
sns.heatmap(good.isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
bad.describe()
# Out:
#          population        amount           psk       balance  \
# count  6.756300e+04  6.718900e+04  6.718900e+04  6.718900e+04
# mean   3.249353e+05  3.591734e+04  3.850126e+02  4.177295e+04
# std    7.232128e+05  1.381645e+05  9.069856e+03  9.989535e+05
# min    4.271000e+03  0.000000e+00 -3.251000e+03  0.000000e+00
# 25%    3.719700e+04  5.000000e+03  2.389300e+01  1.300000e+03
# 50%    1.053840e+05  1.000000e+04  3.560000e+02  8.050000e+03
# 75%    3.153110e+05  2.004000e+04  3.650000e+02  2.068900e+04
# max    5.383890e+06  8.000000e+06  1.939059e+06  2.483119e+08
#
#        current_indebtedness       expired  next_payment  \
# count          6.718900e+04  6.718900e+04  6.718900e+04
# mean           1.220512e+04  2.929127e+03  2.218705e+03
# std            8.805972e+04  3.378885e+04  3.250224e+04
# min            0.000000e+00  0.000000e+00  0.000000e+00
# 25%            0.000000e+00  0.000000e+00  0.000000e+00
# 50%            0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
colours = ['#000000', '#ffff00']
sns.heatmap(bad.isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
df = sns.load_dataset(good)
sns.pairplot(df, hue="species")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-cf7c782b8188> in <cell line: 1>()
# ----> 1 df = sns.load_dataset(good)
#       2 sns.pairplot(df, hue="species")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     577             "it is not necessary to use this function before plotting."
#     578         )
# --> 579         raise TypeError(err)
#     580
#     581     url = f"https://raw.githubusercontent.com/mwaskom/seaborn-data/master/{name}.csv"
#
# TypeError: This function accepts only strings (the name of an example dataset). You passed a pandas DataFrame. If you have your own dataset, it is not necessary to use this function before plotting.
